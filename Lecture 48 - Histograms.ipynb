# %%
# Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Stats
from scipy import stats

# %%
#Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import webbrowser

# %%
# %matplotlib inline

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
url
# Out:
# 'http://en.wikipedia.org/wiki/Histogram'

# %%
webbrowser.open(url)
# Out:
# True

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  3.,   8.,   8.,  17.,  28.,  18.,   9.,   6.,   2.,   1.]),
#  array([-2.58820821, -2.03139438, -1.47458056, -0.91776674, -0.36095292,
#          0.19586091,  0.75267473,  1.30948855,  1.86630237,  2.4231162 ,
#          2.97993002]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([  1.,   0.,   1.,   5.,   6.,  19.,  15.,  15.,  11.,   7.]),
#  array([-3.7935275 , -3.23947276, -2.68541801, -2.13136327, -1.57730853,
#         -1.02325378, -0.46919904,  0.0848557 ,  0.63891045,  1.19296519,
#          1.74701993]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha=.5,bins=20)
plt.hist(dataset2,normed=True,alpha=.5,bins=20)
# Out:
# (array([ 0.0451219 ,  0.        ,  0.        ,  0.        ,  0.0451219 ,
#          0.        ,  0.        ,  0.22560948,  0.09024379,  0.18048758,
#          0.36097516,  0.49634085,  0.45121895,  0.22560948,  0.36097516,
#          0.31585327,  0.40609706,  0.09024379,  0.22560948,  0.09024379]),
#  array([-3.7935275 , -3.51650013, -3.23947276, -2.96244538, -2.68541801,
#         -2.40839064, -2.13136327, -1.8543359 , -1.57730853, -1.30028115,
#         -1.02325378, -0.74622641, -0.46919904, -0.19217167,  0.0848557 ,
#          0.36188308,  0.63891045,  0.91593782,  1.19296519,  1.46999256,
#          1.74701993]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')

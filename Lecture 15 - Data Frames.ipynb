# %%
import numpy as np

import pandas as pd

from pandas import Series, DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL', 'Season',
#        'Total', 'Games', 'Division'],
#       dtype='object')

# %%
nfl_frame['First']
# Out:
# 0     0.570
# 1     0.568
# 2    37.000
# 3     0.561
# 4     9.000
# Name: First, dtype: float64

# %%
DataFrame(nfl_frame, columns=['Team','First','Total'])
# Out:
#       Team   First  Total
# 0  Chicago   0.570    NFC
# 1   Dallas   0.568    NFC
# 2    Green  37.000  1,304
# 3    Miami   0.561    AFC
# 4      New   9.000    852

# %%
DataFrame(nfl_frame, columns=['Team','First','Total','Stadium'])
# Out:
#       Team   First  Total  Stadium
# 0  Chicago   0.570    NFC      NaN
# 1   Dallas   0.568    NFC      NaN
# 2    Green  37.000  1,304      NaN
# 3    Miami   0.561    AFC      NaN
# 4      New   9.000    852      NaN

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
nfl_frame.head()
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
nfl_frame.head(2)
# Out:
#    Rank     Team      Won Lost  Tied  Pct.  First     NFL Season Total  Games  \
# 0     1  Chicago    Bears  741   555    42  0.570  1920.0  1,338   NFC  North
# 1     2   Dallas  Cowboys  480   364     6  0.568  1960.0    850   NFC   East
#
#   Division
# 0      NaN
# 1      NaN

# %%
nfl_frame.tail(2)
# Out:
#    Rank   Team       Won      Lost  Tied  Pct.  First       NFL Season Total  \
# 3     4  Miami  Dolphins       429   335     4  0.561  1966.000    768   AFC
# 4     5    New   England  Patriots   462   381  9.000     0.548   1960   852
#
#   Games Division
# 3  East      NaN
# 4   AFC     East

# %%
nfl_frame.tail(3)
# Out:
#    Rank   Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 2     3  Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4  Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5    New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total Games Division
# 2  1,304   NFC    North
# 3    AFC  East      NaN
# 4    852   AFC     East

# %%
nfl_frame.ix[3]
# Out:
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             429
# Tied             335
# Pct.               4
# First          0.561
# NFL             1966
# Season           768
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Staium"

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division        Stadium
# 0    NFC  North      NaN  Levi's Staium
# 1    NFC   East      NaN  Levi's Staium
# 2  1,304    NFC    North  Levi's Staium
# 3    AFC   East      NaN  Levi's Staium
# 4    852    AFC     East  Levi's Staium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division  Stadium
# 0    NFC  North      NaN        0
# 1    NFC   East      NaN        1
# 2  1,304    NFC    North        2
# 3    AFC   East      NaN        3
# 4    852    AFC     East        4

# %%
stadiums = Series(["Levi's Stadiums","AT&T Stadium"],index= [4,0])
stadiums
# Out:
# 4    Levi's Stadiums
# 0       AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division          Stadium
# 0    NFC  North      NaN     AT&T Stadium
# 1    NFC   East      NaN              NaN
# 2  1,304    NFC    North              NaN
# 3    AFC   East      NaN              NaN
# 4    852    AFC     East  Levi's Stadiums

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
data = {'City':['SF', 'LA', 'NYC'],'Population':[837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
